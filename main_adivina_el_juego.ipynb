# %% [markdown]
#   <p style="text-align: right;margin: 0;">Universidad Complutense de Madrid</p>
#   <p style="text-align: right;margin: 0;">Master Data Science, Big Data & Business Analytics</p>
#   <p style="text-align: right;margin: 0;">José Javier Galán</p>
#   <p style="text-align: right;margin: 0;">María Carolina González Bernal</p>
#   <p style="text-align: right;margin: 0;">Python básico I</p>
#   <p style="text-align: right;font-size: 14px; margin: 0;">20 de noviembre de 2025</p>

# %% [markdown]
# <p style="color: #000000; font-size: 32px; font-weight: bold; text-align: center; margin-top: 20px;">
# Adivina    el número
# </p>

# %%
'''
Adivina el numero (1-1000)

- Dos modos de juego, individual o en pareja.
- Tres niveles de dificultad.
- Registro partidas. 
- Visualización de resultados. 

requierements: 
pip install openpyxl
pip install matplotlib
'''


# %load_ext autoreload
# %autoreload 2

from modulos.menu import menu
import matplotlib.pyplot as plt
import matplotlib.image as mpimg 

img = mpimg.imread('img/header.png')
plt.imshow(img)
plt.axis('off')
plt.show()

if __name__ == "__main__":
  menu()
# Out:
# Adivina el número
#
# ¿Qué quieres hacer?
#
# 1. Partida modo solitario
# 2. Partido 2 jugadores
# 3. Estadística
# 4. Salir
# Selecciona una opción númerica:  3
# 1. Últimas 20 Partidas
# 2. Mejores Jugadores
# 3. Partidas Ganadas o Perdidas
# 4. Regresar
# Selecciona una opción númerica:  1
#    Últimas partidas
#                   Fecha     Nombre       Modo Dificultad  Intentos Resultado
# 33  2025-11-12 14:11:02      Jorge  Solitario      Medio         4   Perdido
# 34  2025-11-12 14:19:30   Gabriela      Doble      Fácil         2    Ganado
# 35  2025-11-12 14:27:11  Alejandro  Solitario    Difícil         3    Ganado
# 36  2025-11-12 14:36:00     Manuel  Solitario      Medio         5   Perdido
# 37  2025-11-12 14:43:12      Lucía  Solitario      Medio         3    Ganado
# 38  2025-11-12 14:51:55        Ana  Solitario    Difícil         6   Perdido
# 39  2025-11-12 15:00:30    Ricardo  Solitario      Medio         2    Ganado
# 40  2025-11-12 15:08:44     Sergio      Doble    Difícil         2    Ganado
# 41  2025-11-12 15:17:02   Catalina  Solitario    Difícil         1    Ganado
# 42  2025-11-13 14:05:11     Manuel  Solitario    Difícil         7   Perdido
# 43  2025-11-13 14:12:40      Jorge  Solitario      Fácil         2    Ganado
# 44  2025-11-13 14:20:33   Gabriela  Solitario      Medio         3    Ganado
# 45  2025-11-13 14:28:12        Ana  Solitario      Fácil         4    Ganado
# 46  2025-11-13 14:35:50    Ricardo      Doble      Medio         3    Ganado
# 47  2025-11-13 14:44:22   Catalina  Solitario    Difícil         1    Ganado
# 48  2025-11-13 14:52:55      Lucía  Solitario    Difícil         5   Perdido
# 49  2025-11-13 15:00:37  Alejandro  Solitario      Medio         2    Ganado
# 50  2025-11-13 15:09:11     Sergio  Solitario    Difícil         3    Ganado
# 51  2025-11-13 15:16:50   Catalina  Solitario    Difícil         1    Ganado
# 52  2025-11-13 23:50:30   Catalina      Doble    Difícil         1    Ganado
# 1. Últimas 20 Partidas
# 2. Mejores Jugadores
# 3. Partidas Ganadas o Perdidas
# 4. Regresar
# Selecciona una opción númerica:  2
# 1. Últimas 20 Partidas
# 2. Mejores Jugadores
# 3. Partidas Ganadas o Perdidas
# 4. Regresar
# Selecciona una opción númerica:  3
# 1. Últimas 20 Partidas
# 2. Mejores Jugadores
# 3. Partidas Ganadas o Perdidas
# 4. Regresar
# Selecciona una opción númerica:  4
# Adivina el número
#
# ¿Qué quieres hacer?
#
# 1. Partida modo solitario
# 2. Partido 2 jugadores
# 3. Estadística
# 4. Salir
# Selecciona una opción númerica:  2
# ¡Comenzemos a jugar!
#
# Modo 2 Jugadores
# Elige el nivel de dificultad:
# 1. Fácil → 20 intentos
# 2. Medio → 12 intentos
# 3. Difícil → 5 intentos
#  3
# Piensa el número que quieres que adivine el segundo jugador...
# Escribe el número entre 1 y 1000:
#  ········
# Ingresa tu primer intento:
# Tienes 5 intentos:  465
# Intenta con un numero MENOR
# Tienes 4 intentos:  57
# Intenta con un numero MAYOR
# Tienes 3 intentos:  123
# ¡Lo lograste, adivinaste el número!
# Registra tu partida
#  Nombre de quien adivinó:  Catalina
# Adivina el número
#
# ¿Qué quieres hacer?
#
# 1. Partida modo solitario
# 2. Partido 2 jugadores
# 3. Estadística
# 4. Salir
# Selecciona una opción númerica:  4
# ¡Nos vemos pronto!
